# %% [markdown]
# <a href="https://colab.research.google.com/github/Chiranjit680/Saahaita/blob/main/TextClassification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import pandas as pd
import torch.nn as nn

# %%
# For local VS Code environment
# Update the path to your local CSV file
# Example: dataset = pd.read_csv('C:/path/to/your/tweets.csv')
print("📁 Please update the file path in the next cell to point to your local tweets.csv file")
# Out:
# 📁 Please update the file path in the next cell to point to your local tweets.csv file

# %%
# Update this path to your local tweets.csv file
# dataset = pd.read_csv('C:/path/to/your/tweets.csv')
# For now, let's create a sample dataset for testing
import pandas as pd

# Sample data for testing (replace with actual CSV loading)
dataset=pd.read_csv('tweets.csv')

df = pd.DataFrame(dataset)
df.head()
# Out:
#    id keyword        location  \
# 0   0  ablaze             NaN
# 1   1  ablaze             NaN
# 2   2  ablaze   New York City
# 3   3  ablaze  Morgantown, WV
# 4   4  ablaze             NaN
#
#                                                 text  target
# 0  Communal violence in Bhainsa, Telangana. "Ston...       1
# 1  Telangana: Section 144 has been imposed in Bha...       1
# 2  Arsonist sets cars ablaze at dealership https:...       1
# 3  Arsonist sets cars ablaze at dealership https:...       1
# 4  "Lord Jesus, your love brings freedom and pard...       0

# %%
df["text"]=df["text"].str.lower()

# %%
import re

def remove_urls(text):
    url_pattern = r'https?://\S+|www\.\S+'
    return re.sub(url_pattern, '', text)

# %%
df["text"]=df["text"].apply(remove_urls)

# %%
import string
def remove_punc(text):
    exclude=string.punctuation
    return text.translate(str.maketrans('', '', exclude))

# %%
df["text"]=df["text"].apply(remove_punc)

# %%
slang_dict = {
    "AFAIK": "As Far As I Know",
    "AFK": "Away From Keyboard",
    "ASAP": "As Soon As Possible",
    "ATK": "At The Keyboard",
    "ATM": "At The Moment",
    "A3": "Anytime, Anywhere, Anyplace",
    "BAK": "Back At Keyboard",
    "BBL": "Be Back Later",
    "BBS": "Be Back Soon",
    "BFN": "Bye For Now",
    "B4N": "Bye For Now",
    "BRB": "Be Right Back",
    "BRT": "Be Right There",
    "BTW": "By The Way",
    "B4": "Before",
    "CU": "See You",
    "CUL8R": "See You Later",
    "CYA": "See You",
    "FAQ": "Frequently Asked Questions",
    "FC": "Fingers Crossed",
    "FWIW": "For What It's Worth",
    "FYI": "For Your Information",
    "GAL": "Get A Life",
    "GG": "Good Game",
    "GN": "Good Night",
    "GMTA": "Great Minds Think Alike",
    "GR8": "Great!",
    "G9": "Genius",
    "IC": "I See",
    "ICQ": "I Seek you (also a chat program)",
    "ILU": "I Love You",
    "IMHO": "In My Honest/Humble Opinion",
    "IMO": "In My Opinion",
    "IOW": "In Other Words",
    "IRL": "In Real Life",
    "KISS": "Keep It Simple, Stupid",
    "LDR": "Long Distance Relationship",
    "LMAO": "Laugh My A** Off",
    "LOL": "Laughing Out Loud",
    "LTNS": "Long Time No See",
    "L8R": "Later",
    "MTE": "My Thoughts Exactly",
    "M8": "Mate",
    "NRN": "No Reply Necessary",
    "OIC": "Oh I See",
    "PITA": "Pain In The A**",
    "PRT": "Party",
    "PRW": "Parents Are Watching",
    "QPSA?": "Que Pasa?",
    "ROFL": "Rolling On The Floor Laughing",
    "ROFLOL": "Rolling On The Floor Laughing Out Loud",
    "ROTFLMAO": "Rolling On The Floor Laughing My A** Off",
    "SK8": "Skate",
    "STATS": "Your sex and age",
    "ASL": "Age, Sex, Location",
    "THX": "Thank You",
    "TTFN": "Ta-Ta For Now!",
    "TTYL": "Talk To You Later",
    "U": "You",
    "U2": "You Too",
    "U4E": "Yours For Ever",
    "WB": "Welcome Back",
    "WTF": "What The F...",
    "WTG": "Way To Go!",
    "WUF": "Where Are You From?",
    "W8": "Wait...",
    "7K": "Sick:-D Laugher",
    "TFW": "That Feeling When",
    "MFW": "My Face When",
    "MRW": "My Reaction When",
    "IFYP": "I Feel Your Pain",
    "TNTL": "Trying Not To Laugh",
    "JK": "Just Kidding",
    "IDC": "I Don't Care",
    "ILY": "I Love You",
    "IMU": "I Miss You",
    "ADIH": "Another Day In Hell",
    "ZZZ": "Sleeping, Bored, Tired",
    "WYWH": "Wish You Were Here",
    "TIME": "Tears In My Eyes",
    "BAE": "Before Anyone Else",
    "FIMH": "Forever In My Heart",
    "BSAAW": "Big Smile And A Wink",
    "BWL": "Bursting With Laughter",
    "BFF": "Best Friends Forever",
    "CSL": "Can't Stop Laughing"
}

def remove_abbr(text):
    words = text.split(" ")
    # Fix: Use list comprehension instead of words.replace()
    processed_words = []
    for word in words:
        if word.upper() in slang_dict:
            processed_words.append(slang_dict[word.upper()])
        else:
            processed_words.append(word)
    return " ".join(processed_words)

# %%
df["text"]=df["text"].apply(remove_abbr)

# %%
# Step 1: Install nltk if not already
# !rm -f nltk.py
# !rm -f nltk.pyc
# !rm -rf __pycache__

# !pip install nltk

# Step 2: Import nltk and download stopwords
import nltk
nltk.download('stopwords')

# Step 3: Import stopwords
from nltk.corpus import stopwords

# Step 4: Use stopwords
stop_words = stopwords.words('english')
print(stop_words[:10])
# Out:
# ...
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# %%
df["text"]=df["text"].apply(remove_stopwords)

# %%
disaster_classes = {
    'Natural Disasters': [
        'earthquake', 'aftershock', 'seismic', 'tsunami', 'landslide', 'lava', 'volcano',
        'mudslide', 'avalanche', 'cyclone', 'hurricane', 'tornado', 'typhoon', 'twister',
        'storm', 'snowstorm', 'rainstorm', 'sandstorm', 'dust storm', 'windstorm',
        'natural disaster', 'heat wave', 'flood', 'flooding', 'floods', 'deluge', 'inundated',
        'inundation', 'hail', 'hailstorm', 'lightning', 'thunderstorm', 'whirlwind'
    ],
    'Fires': [
        'fire', 'wildfire', 'forest fire', 'forest fires', 'bush fires', 'ablaze', 'blaze',
        'blazing', 'smoke', 'burned', 'burning', 'flames', 'buildings burning',
        'buildings on fire', 'hellfire', 'arson', 'arsonist', 'engulfed', 'flattened',
        'scorched', 'razed', 'flared', 'incinerated', 'charred', 'conflagration', 'fire truck'
    ],
    'Explosions': [
        'bomb', 'bombed', 'bombing', 'explosion', 'explode', 'exploded', 'detonate',
        'suicide bomb', 'suicide bomber', 'suicide bombing', 'blown up', 'blew up', 'meltdown',
        'loud bang', 'wreck', 'wreckage', 'wrecked', 'obliterate', 'obliterated', 'obliteration',
        'blast', 'devastation', 'devastated', 'destruction', 'annihilation', 'annihilated',
        'apocalypse', 'catastrophe', 'catastrophic'
    ],
    'Accidents/Collisions': [
        'crash', 'crashed', 'collision', 'collide', 'collided', 'accident', 'airplane accident',
        'wreck', 'wreckage', 'wrecked', 'sinkhole', 'sinking', 'fall', 'cliff fall', 'demolish',
        'demolished', 'demolition', 'bridge collapse', 'collapse', 'collapsed',
        'structural failure', 'flattened', 'damage', 'ruin', 'blight', 'desolate', 'desolation'
    ],
    'Violence/Attacks': [
        'attack', 'attacked', 'mass murder', 'massacre', 'mass murderer', 'hostage', 'hostages',
        'hijack', 'hijacker', 'hijacking', 'shooting', 'riot', 'rioting', 'battle', 'war zone',
        'military', 'army', 'threat', 'weapon', 'weapons', 'trouble', 'mayhem', 'pandemonium',
        'fear', 'eyewitness', 'screamed', 'screaming', 'screams', 'police'
    ],
    'Medical Emergencies': [
        'ambulance', 'injured', 'injuries', 'injury', 'fatal', 'fatality', 'fatalities',
        'wounded', 'wounds', 'casualty', 'casualties', 'trauma', 'traumatised', 'stretcher',
        'blood', 'bloody', 'bleeding', 'survivors', 'survive', 'survived', 'dead', 'death',
        'deaths', 'drown', 'drowned', 'drowning', 'electrocute', 'electrocuted', 'refugees'
    ],
    'Weather Events': [
        'storm', 'thunderstorm', 'hailstorm', 'snowstorm', 'rainstorm', 'cyclone', 'hurricane',
        'blizzard', 'twister', 'typhoon', 'windstorm', 'heat wave', 'lightning', 'thunder',
        'deluge', 'inundation', 'sandstorm', 'dust storm', 'violent storm', 'whirlwind'
    ],
    'Structural Failures': [
        'bridge collapse', 'building collapse', 'collapsed', 'collapse', 'wrecked', 'wreckage',
        'demolition', 'demolished', 'demolish', 'blight', 'flattened', 'crushed', 'crush',
        'sinking', 'sinkhole', 'destruction', 'damaged', 'destroyed', 'destroy', 'obliterated',
        'ruin', 'razed', 'desolate', 'desolation', 'structural failure', 'devastated'
    ],
    'Evacuation & Emergency Response': [
        'emergency', 'emergency plan', 'emergency services', 'first responders', 'rescue',
        'rescued', 'rescuers', 'evacuate', 'evacuated', 'evacuation', 'curfew', 'quarantine',
        'quarantined', 'panic', 'panicking', 'eyewitness', 'refugees', 'help', 'sirens',
        'siren', 'screamed', 'screams', 'screaming', 'fear', 'survive', 'survivors'
    ],
    'Radiological/Chemical/Biological Hazards': [
        'nuclear disaster', 'radiation emergency', 'chemical emergency', 'bioterror',
        'bioterrorism', 'outbreak', 'quarantine', 'quarantined', 'pandemonium', 'hazard',
        'hazardous', 'apocalypse', 'contamination', 'infected', 'epidemic', 'plague',
        'infectious', 'radioactive', 'radioactivity', 'nuclear reactor', 'toxic', 'biohazard',
        'chemical spill', 'oil spill', 'spill', 'gas leak'
    ]
}

# %%
def classify_disaster(text):
    for category, keywords in disaster_classes.items():
        for word in keywords:
            if word in text:
                return category
    return 'unknown'

# Apply classification
# df['disaster_category'] = df['text'].apply(classify_disaster)
df['disaster_category']=df['keyword'].apply(classify_disaster)

# %%
df.head()
# Out:
#    id keyword        location  \
# 0   0  ablaze             NaN
# 1   1  ablaze             NaN
# 2   2  ablaze   New York City
# 3   3  ablaze  Morgantown, WV
# 4   4  ablaze             NaN
#
#                                                 text  target disaster_category
# 0  communal violence bhainsa telangana stones pel...       1             Fires
# 1  telangana section 144 imposed bhainsa january ...       1             Fires
# 2               arsonist sets cars ablaze dealership       1             Fires
# 3               arsonist sets cars ablaze dealership       1             Fires
# 4  lord jesus love brings freedom pardon fill hol...       0             Fires

# %%
df["disaster_category"].unique()
# Out:
# array(['Fires', 'Accidents/Collisions', 'Natural Disasters',
#        'Medical Emergencies', 'Explosions', 'unknown', 'Violence/Attacks',
#        'Radiological/Chemical/Biological Hazards', 'Weather Events',
#        'Evacuation & Emergency Response', 'Structural Failures'],
#       dtype=object)

# %%
df=df[df["disaster_category"]!="unknown"]

# %%
df = df.drop(columns=["location", "target", "id", "keyword"], errors='ignore')

# %%
df
# Out:
#                                                     text disaster_category
# 0      communal violence bhainsa telangana stones pel...             Fires
# 1      telangana section 144 imposed bhainsa january ...             Fires
# 2                   arsonist sets cars ablaze dealership             Fires
# 3                   arsonist sets cars ablaze dealership             Fires
# 4      lord jesus love brings freedom pardon fill hol...             Fires
# ...                                                  ...               ...
# 11365  media warned us well advance wrecked whole nig...        Explosions
# 11366  feel directly attacked 💀 consider moonbin amp ...        Explosions
# 11367  feel directly attacked 💀 consider moonbin amp ...        Explosions
# 11368  ok remember outcast nd dora au au wrecked nerv...        Explosions
# 11369               jake corway wrecked running 14th irp        Explosions
#
# [9551 rows x 2 columns]

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')

stop_words = set(stopwords.words('english'))
lemmatizer = WordNetLemmatizer()

def preprocess(text):
    # remove non-alphabetic characters and lower the text
    text = re.sub(r"[^a-zA-Z\s]", "", str(text).lower())
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(word) for word in tokens if word not in stop_words]
    return " ".join(tokens)

df['text'] = df['text'].apply(preprocess)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df
# Out:
#                                                     text disaster_category
# 0      communal violence bhainsa telangana stone pelt...             Fires
# 1      telangana section imposed bhainsa january clas...             Fires
# 2                     arsonist set car ablaze dealership             Fires
# 3                     arsonist set car ablaze dealership             Fires
# 4      lord jesus love brings freedom pardon fill hol...             Fires
# ...                                                  ...               ...
# 11365  medium warned u well advance wrecked whole nig...        Explosions
# 11366  feel directly attacked consider moonbin amp ji...        Explosions
# 11367  feel directly attacked consider moonbin amp ji...        Explosions
# 11368  ok remember outcast nd dora au au wrecked nerv...        Explosions
# 11369                 jake corway wrecked running th irp        Explosions
#
# [9551 rows x 2 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df["label"]=le.fit_transform(df["disaster_category"])

# %%
df
# Out:
#                                                     text disaster_category  \
# 0      communal violence bhainsa telangana stone pelt...             Fires
# 1      telangana section imposed bhainsa january clas...             Fires
# 2                     arsonist set car ablaze dealership             Fires
# 3                     arsonist set car ablaze dealership             Fires
# 4      lord jesus love brings freedom pardon fill hol...             Fires
# ...                                                  ...               ...
# 11365  medium warned u well advance wrecked whole nig...        Explosions
# 11366  feel directly attacked consider moonbin amp ji...        Explosions
# 11367  feel directly attacked consider moonbin amp ji...        Explosions
# 11368  ok remember outcast nd dora au au wrecked nerv...        Explosions
# 11369                 jake corway wrecked running th irp        Explosions
#
#        label
# 0          3
# 1          3
# 2          3
# ...

# %%
df["text"] = df["text"].apply(str)

from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer=TfidfVectorizer()
X=vectorizer.fit_transform(df["text"])
Y=df["label"]
from sklearn.model_selection import train_test_split
X_train_xg,X_test_xg,Y_train_xg,Y_test_xg=train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
X_train_xg[0]
# Out:
# <1x17739 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15 stored elements in Compressed Sparse Row format>

# %%
df["text"]
# Out:
# 0        communal violence bhainsa telangana stone pelt...
# 1        telangana section imposed bhainsa january clas...
# 2                       arsonist set car ablaze dealership
# 3                       arsonist set car ablaze dealership
# 4        lord jesus love brings freedom pardon fill hol...
#                                ...
# 11365    medium warned u well advance wrecked whole nig...
# 11366    feel directly attacked consider moonbin amp ji...
# 11367    feel directly attacked consider moonbin amp ji...
# 11368    ok remember outcast nd dora au au wrecked nerv...
# 11369                   jake corway wrecked running th irp
# Name: text, Length: 9551, dtype: object

# %%
import spacy
tokenizer=spacy.load("en_core_web_sm")
df["text"]=df["text"].apply(tokenizer)
df["text"].head()
# Out:
# 0    (communal, violence, bhainsa, telangana, stone...
# 1    (telangana, section, imposed, bhainsa, january...
# 2             (arsonist, set, car, ablaze, dealership)
# 3             (arsonist, set, car, ablaze, dealership)
# 4    (lord, jesus, love, brings, freedom, pardon, f...
# Name: text, dtype: object

# %%
df

# %%
from google.colab import files

# Save DataFrame as CSV
df.to_csv("tweets_tokenized.csv", index=False)

# Download the file
files.download("tweets_tokenized.csv")

# %%
df
# Out:
#                                                     text disaster_category  \
# 0      (communal, violence, bhainsa, telangana, stone...             Fires
# 1      (telangana, section, imposed, bhainsa, january...             Fires
# 2               (arsonist, set, car, ablaze, dealership)             Fires
# 3               (arsonist, set, car, ablaze, dealership)             Fires
# 4      (lord, jesus, love, brings, freedom, pardon, f...             Fires
# ...                                                  ...               ...
# 11365  (medium, warned, u, well, advance, wrecked, wh...        Explosions
# 11366  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11367  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11368  (ok, remember, outcast, nd, dora, au, au, wrec...        Explosions
# 11369          (jake, corway, wrecked, running, th, irp)        Explosions
#
#        label
# 0          3
# 1          3
# 2          3
# ...

# %%
from gensim.models import Word2Vec, KeyedVectors

sentences = [[token.text for token in doc] for doc in df["text"]]
embedding_model = Word2Vec(
    sentences=sentences,
    vector_size=100,
    window=5,
    min_count=1,
    workers=4,
    epochs=50  # You can set epochs here
)

embedding_model.save("word2vec_selftrained.model")

# %%
df["numerical_text"]=df["text"].apply(lambda x: [embedding_model.wv[word.text] for word in x])

# %%
for label in df['label'].unique():
    print(label, ":", (df['label'] == label).sum())
# Out:
# 3 : 1141
# 0 : 1144
# 5 : 1536
# 4 : 1671
# 2 : 1127
# 8 : 1453
# 6 : 312
# 9 : 70
# 1 : 883
# 7 : 214

# %%
df
# Out:
#                                                     text disaster_category  \
# 0      (communal, violence, bhainsa, telangana, stone...             Fires
# 1      (telangana, section, imposed, bhainsa, january...             Fires
# 2               (arsonist, set, car, ablaze, dealership)             Fires
# 3               (arsonist, set, car, ablaze, dealership)             Fires
# 4      (lord, jesus, love, brings, freedom, pardon, f...             Fires
# ...                                                  ...               ...
# 11365  (medium, warned, u, well, advance, wrecked, wh...        Explosions
# 11366  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11367  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11368  (ok, remember, outcast, nd, dora, au, au, wrec...        Explosions
# 11369          (jake, corway, wrecked, running, th, irp)        Explosions
#
#        label                                     numerical_text
# ...

# %%
# def text_to_indices(text):
#     numerical_text=[]
#     for token in text:
#         if token.text in vocab:
#             numerical_text.append(vocab[token.text])
#         else:
#             numerical_text.append(vocab["<unk>"])
#     return numerical_text
# df["numerical_text"]=df["text"].apply(text_to_indices)

# %%
df
# Out:
#                                                     text disaster_category  \
# 0      (communal, violence, bhainsa, telangana, stone...             Fires
# 1      (telangana, section, imposed, bhainsa, january...             Fires
# 2               (arsonist, set, car, ablaze, dealership)             Fires
# 3               (arsonist, set, car, ablaze, dealership)             Fires
# 4      (lord, jesus, love, brings, freedom, pardon, f...             Fires
# ...                                                  ...               ...
# 11365  (medium, warned, u, well, advance, wrecked, wh...        Explosions
# 11366  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11367  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11368  (ok, remember, outcast, nd, dora, au, au, wrec...        Explosions
# 11369          (jake, corway, wrecked, running, th, irp)        Explosions
#
#        label                                     numerical_text
# ...

# %%
for label in df["label"].unique():
    print(label, ":", (df["label"] == label).sum())
# Out:
# 3 : 1141
# 0 : 1144
# 5 : 1536
# 4 : 1671
# 2 : 1127
# 8 : 1453
# 6 : 312
# 9 : 70
# 1 : 883
# 7 : 214

# %%
df
# Out:
#                                                     text disaster_category  \
# 0      (communal, violence, bhainsa, telangana, stone...             Fires
# 1      (telangana, section, imposed, bhainsa, january...             Fires
# 2               (arsonist, set, car, ablaze, dealership)             Fires
# 3               (arsonist, set, car, ablaze, dealership)             Fires
# 4      (lord, jesus, love, brings, freedom, pardon, f...             Fires
# ...                                                  ...               ...
# 11365  (medium, warned, u, well, advance, wrecked, wh...        Explosions
# 11366  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11367  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11368  (ok, remember, outcast, nd, dora, au, au, wrec...        Explosions
# 11369          (jake, corway, wrecked, running, th, irp)        Explosions
#
#        label                                     numerical_text
# ...

# %%
maxlen=0
for text in df["numerical_text"]:
    if len(text)>maxlen:
        maxlen=len(text)
maxlen
# Out:
# 24

# %%
import pandas as pd
import numpy as np

embedding_dim = 100 # Assuming embedding dimension is 100 based on Word2Vec model definition

for i in range(len(df["numerical_text"])):
    text = df["numerical_text"].iloc[i]

    # Handle NaN values and convert arrays/non-lists to lists
    if text is None or (isinstance(text, float) and np.isnan(text)) or not hasattr(text, '__len__'):
        text = []
    elif isinstance(text, np.ndarray):
        text = text.tolist()
    elif not isinstance(text, list):
        text = []

    zeros_to_add = maxlen - len(text)
    if zeros_to_add > 0:
        # Pad with zero vectors of the correct dimension
        zero_vector = np.zeros(embedding_dim).tolist()
        text = text + [zero_vector] * zeros_to_add

    df.at[df.index[i], "numerical_text"] = text

# %%
sampled_df=df.sample(frac=0.6,random_state=42)

# %%
len(sampled_df["numerical_text"][2])
# Out:
# 24

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(sampled_df["numerical_text"],sampled_df["label"],test_size=0.2,random_state=42)

# %%
df
# Out:
#                                                     text disaster_category  \
# 0      (communal, violence, bhainsa, telangana, stone...             Fires
# 1      (telangana, section, imposed, bhainsa, january...             Fires
# 2               (arsonist, set, car, ablaze, dealership)             Fires
# 3               (arsonist, set, car, ablaze, dealership)             Fires
# 4      (lord, jesus, love, brings, freedom, pardon, f...             Fires
# ...                                                  ...               ...
# 11365  (medium, warned, u, well, advance, wrecked, wh...        Explosions
# 11366  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11367  (feel, directly, attacked, consider, moonbin, ...        Explosions
# 11368  (ok, remember, outcast, nd, dora, au, au, wrec...        Explosions
# 11369          (jake, corway, wrecked, running, th, irp)        Explosions
#
#        label                                     numerical_text
# ...

# %%
X_train_tensor=torch.tensor([item for sublist in X_train.tolist() for item in sublist])
Y_train_tensor=torch.tensor(Y_train.tolist())
X_test_tensor=torch.tensor([item for sublist in X_test.tolist() for item in sublist])
Y_test_tensor=torch.tensor(Y_test.tolist())

# %%
print(len(X_train))
# Out:
# 4584

# %%
from torch.utils.data import Dataset, DataLoader
class CustomDataset(Dataset):
  def __init__(self, data, labels):
    self.data = data
    self.labels = labels

  def __len__(self):
    return len(self.data)

  def __getitem__(self, index):
    return self.data[index], self.labels[index]

# %%
dataloader=DataLoader(CustomDataset(X_train_tensor,Y_train_tensor),batch_size=32,shuffle=True)

# %%
import torch
import torch.nn as nn

class LSTMModel(nn.Module):
    def __init__(self, vocab_size=26, embedding_dim=256, hidden_dim=512, output_dim=10, n_layers=4, bidirectional=False, dropout=0.15, pad_idx=0):
        super().__init__()
        self.bidirectional =bidirectional  # Store bidirectional as instance variable
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=pad_idx)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, batch_first=True, num_layers=n_layers, bidirectional=bidirectional, dropout=dropout if n_layers > 1 else 0)
        self.attention=nn.MultiheadAttention(embed_dim=hidden_dim * 2 if bidirectional else hidden_dim, num_heads=4, dropout=dropout)
        self.fc= nn.Sequential(
            nn.Dropout(dropout),
            nn.Linear(hidden_dim * 2 if bidirectional else hidden_dim, hidden_dim // 2),
            nn.BatchNorm1d(hidden_dim // 2),
            nn.ReLU(),
            nn.Dropout(dropout * 0.5),
            nn.Linear(hidden_dim // 2, hidden_dim // 4),
            nn.BatchNorm1d(hidden_dim // 4),
            nn.ReLU(),
            nn.Linear(hidden_dim // 4, output_dim)
        )
        # self.fc=nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)


    def forward(self, text):
        embedded = self.dropout(self.embedding(text))
        out, (hidden, cell) = self.rnn(embedded)

        if self.bidirectional:
            hidden = torch.cat((hidden[-2], hidden[-1]), dim=1)
        else:
            hidden = hidden[-1]

        output = self.fc(hidden)
        return output

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %% [markdown]
# # 🧠 Model Training Section
#
# This section covers:
# - Setting up the LSTM model
# - Configuring training parameters
# - Training the model on disaster tweet data
# - Evaluating performance

# %%
vocab_size=len(vocab)

# %%
from sklearn.utils.class_weight import compute_class_weight
import torch
import torch.nn as nn
import numpy as np

def setup_training(model, learning_rate=0.01):
    model.to(device)

    # Get the actual train/test split to ensure we only use training labels
    from sklearn.model_selection import train_test_split
    X_train_local, X_test_local, Y_train_local, Y_test_local = train_test_split(
        sampled_df["numerical_text"], sampled_df["label"], test_size=0.2, random_state=42
    )

    # Use only the training labels for class weight computation
    classes = np.unique(Y_train_local.values)
    class_weights = compute_class_weight('balanced', classes=classes, y=Y_train_local.values)
    # class_weights = torch.tensor(class_weights, dtype=torch.float).to(device)
    criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate, weight_decay=0.01)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='min', factor=0.5, patience=3, verbose=True
    )

    return optimizer, criterion, scheduler

# %%
model=LSTMModel(vocab_size=vocab_size)

# %%
def train(model, dataloader, optimizer, criterion, scheduler, epochs=5):
    for epoch in range(epochs):
        model.train()  # Ensure training mode
        total_loss = 0
        correct = 0
        total = 0

        for data, labels in dataloader:
            data = data.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            output = model(data)
            loss = criterion(output, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()

            total_loss += loss.item()
            pred = output.argmax(dim=1)
            correct += (pred == labels).sum().item()
            total += labels.size(0)

        avg_loss = total_loss / len(dataloader)
        train_accuracy = correct / total
        print(f"Epoch {epoch+1}/{epochs}, Loss: {avg_loss:.4f}, Accuracy: {train_accuracy:.4f}")

        scheduler.step(avg_loss)

# %%
model.to(device)
# Out:
# LSTMModel(
#   (embedding): Embedding(93451, 256, padding_idx=0)
#   (rnn): LSTM(256, 512, num_layers=4, batch_first=True, dropout=0.15)
#   (attention): MultiheadAttention(
#     (out_proj): NonDynamicallyQuantizableLinear(in_features=512, out_features=512, bias=True)
#   )
#   (fc): Sequential(
#     (0): Dropout(p=0.15, inplace=False)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): Dropout(p=0.075, inplace=False)
#     (5): Linear(in_features=256, out_features=128, bias=True)
#     (6): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): ReLU()
#     (8): Linear(in_features=128, out_features=10, bias=True)
#   )
#   (dropout): Dropout(p=0.15, inplace=False)
# )

# %%
train(model, dataloader, *setup_training(model), epochs=30)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-318-1895929631.py in <cell line: 0>()
# ----> 1 train(model, dataloader, *setup_training(model), epochs=30)
#
# /tmp/ipython-input-316-371624681.py in train(model, dataloader, optimizer, criterion, scheduler, epochs)
#       6         total = 0
#       7
# ----> 8         for data, labels in dataloader:
#       9             data = data.to(device)
#      10             labels = labels.to(device)
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
# ...

# %%
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix
import numpy as np
def evaluate_model(model, test_loader, criterion=None, device='cpu'):
    """
    Evaluate the LSTM model on test data

    Args:
        model: Trained LSTM model
        test_loader: DataLoader for test data
        criterion: Loss function (optional)
        device: Device to run evaluation on

    Returns:
        Dictionary containing evaluation metrics
    """
    model.eval()
    model.to(device)

    all_predictions = []
    all_true_labels = []
    total_loss = 0.0

    with torch.no_grad():
        for batch_idx, (data, targets) in enumerate(test_loader):
            data, targets = data.to(device), targets.to(device)

            # Forward pass
            outputs = model(data)

            # Calculate loss if criterion provided
            if criterion is not None:
                loss = criterion(outputs, targets)
                total_loss += loss.item()

            # Get predictions
            predictions = torch.argmax(outputs, dim=1)

            # Store results
            all_predictions.extend(predictions.cpu().numpy())
            all_true_labels.extend(targets.cpu().numpy())

    # Convert to numpy arrays
    all_predictions = np.array(all_predictions)
    all_true_labels = np.array(all_true_labels)

    # Calculate metrics
    accuracy = accuracy_score(all_true_labels, all_predictions)
    precision, recall, f1, support = precision_recall_fscore_support(
        all_true_labels, all_predictions, average='weighted', zero_division=0
    )

    # Confusion matrix
    cm = confusion_matrix(all_true_labels, all_predictions)

    results = {
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'confusion_matrix': cm,
        'average_loss': total_loss / len(test_loader) if criterion is not None else None
    }

    return results

# %%
testloader = DataLoader(CustomDataset(X_test_tensor, Y_test_tensor), batch_size=32, shuffle=False)
criterion=nn.CrossEntropyLoss()
results = evaluate_model(model, testloader, criterion=criterion , device=device)

# %%
print("Evaluation Results:")
print(f"Accuracy: {results['accuracy']:.4f}")
print(f"Precision: {results['precision']:.4f}")
print(f"Recall: {results['recall']:.4f}")
print(f"F1 Score: {results['f1_score']:.4f}")
print("Confusion Matrix:")
print(results['confusion_matrix'])
print(f"Average Loss: {results['average_loss']:.4f}")
